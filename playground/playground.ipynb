# %%
from dotenv import load_dotenv
load_dotenv("../app/.env")
import sys
sys.path.append("../app")

# %%
import evars
evars.AI_CHAT_MODEL_PROVIDER
# Out:
# 'OPENAI'

# %%
from services.ai.aimodels import chat_model, embedding_model

print(embedding_model.embed("ping").shape)
# Out:
# (3072,)

# %%
from services.websearch.googlesearch.google import google

search_links = google.search(["Adolf Hitler"], 5)
search_links
# Out:
# ['https://de.wikipedia.org/wiki/Adolf_Hitler',
#  'https://www.britannica.com/biography/Adolf-Hitler',
#  'https://www.dhm.de/lemo/biografie/adolf-hitler']

# %%
from services.websearch.webscraper.scraper import webscraper

page = webscraper.scrape("https://de.wikipedia.org/wiki/Adolf_Hitler")
page
# Out:
# [16.05.2025 19:47:59,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): de.wikipedia.org:443
# [16.05.2025 19:47:59,f] [DEBUG] connectionpool.py https://de.wikipedia.org:443 "GET /wiki/Adolf_Hitler HTTP/1.1" 200 197821
# WebPageResult(url='https://de.wikipedia.org/wiki/Adolf_Hitler', content="Adolf Hitler  Wikipedia\n\n\nZum Inhalt springen\n\n\nSuche\n\n\nSuchen\n\n\nAdolf Hitler\n\n\n241 Sprachen\n\n\nAfrikaansAlemannischAragonsngliscAsturianuAzrbaycancaBasa BaliBoarischemaitkaBikol Central ()BetawiBanjarBrezhonegBosanskiBatak MandailingCatalChavacano de Zamboanga / Mng-dng-ngCebuanoCorsuQrmtatarcaetinaKaszbscziCymraegDanskThujZazakiEmilin e rumagnlEnglishEsperantoEspaolEestiEuskaraEstremeuFulfuldeSuomiVroFroysktFranaisNordfriiskFurlanFryskGaeilgeKriyl gwiyannenGidhligGalegoAvae'  / Gychi KonknniGungbeGaelgHausa / Hak-k-ngHawaiiFiji HindiHrvatskiHornjoserbsceKreyl ayisyenMagyarInterlinguaBahasa IndonesiaInterlingueIgboIlokanoIdoslenskaItaliano / inuktitutPatoisLa .lojban.JawaQaraqalpaqshaTaqbaylitKabyYerwa Kanuri / RipoarischKurdKernowekLatinaLadinoLtzebuergeschLingua Franca NovaLugandaLimburgsLadinLombardLietuviLatgauLatvieuMadhurBasa BanyumasanMalagasy MoriMinangkabauBahasa MelayuMaltiMirandsNhuatlNapulitanoPlattdtschNedersaksies NederlandsNorsk nynorskNorsk bokmlNovialDin bizaadChi-ChewaOccitanLivvinkarjalaOromooPangasinanPapiamentuPicardPolskiPiemontisPortugusRuna SimiRumantschRomani hibRomnArmneashtiTarandneIkinyarwanda SarduSicilianuScotsDavvismegiellaSrpskohrvatski / Simple EnglishSloveninaSloveninaChiShonaSoomaaligaShqip / srpskiSranantongoSesothoSeelterskSundaSvenskaKiswahililnskiSakizayaTagalogToliLea faka-TongaTrke / tataraChiTumbuka Ozbekcha / VnetoVepsn kelTing VitWest-VlamsVolapkWalonWinarayYorbVahcuenghZeuws  / Bn-lm-g\n\nLinks bearbeiten\n\n\naus Wikipedia, der freien Enzyklopdie\n\n\nHitler ist eine Weiterleitung auf diesen Artikel. Zu weiteren Bedeutungen von Hitler und Adolf Hitler siehe Hitler (Begriffsklrung).\n\nAdolf Hitler (1938)Unterschrift (1944), vermutlich mit einem Unterschriftenautomaten erzeugt (vgl. Abschnitt Weiterer Kriegsverlauf)\nAdolf Hitler (* 20. April 1889 in Braunau am Inn, sterreich-Ungarn;  30. April 1945 in Berlin) war ein deutscher Politiker sterreichischer Herkunft und von 1933 bis zu seinem Tod Diktator des Deutschen Reichs. Ab 1921 war er Vorsitzender der Nationalsozialistischen Deutschen Arbeiterpartei (NSDAP), von 1933 bis 1945 deutscher Reichskanzler, ab 1934 auch Staatsoberhaupt und ab 1938 Oberbefehlshaber der deutschen Wehrmacht.\nIm November 1923 versuchte er mit einem Putsch von Mnchen aus die Weimarer Republik zu strzen. Mit seiner Schrift Mein Kampf (1925/26) prgte er die antisemitische und rassistische, auf Eroberung von Lebensraum ausgerichtete Ideologie des Nationalsozialismus.\nHitler wurde am 30. Januar 1933 von Reichsprsident Paul von Hindenburg zum deutschen Reichskanzler ernannt. Innerhalb weniger Monate beseitigte sein Regime mit Terror, Notverordnungen, dem Ermchtigungsgesetz, Gleichschaltungsgesetzen, Organisations- und Parteiverboten die Gewaltenteilung, die pluralistische Demokratie, den Fderalismus und den Rechtsstaat. Politische Gegner wurden in Konzentrationslagern inhaftiert, gefoltert und ermordet. 1934 lie Hitler anlsslich des Rhm-Putsches politische Gegner und potenzielle Rivalen in den eigenen Reihen ermorden. Hindenburgs Tod im August 1934 nutzte er, um das Amt des Reichsprsidenten mit dem des Reichskanzlers vereinen zu lassen, und regierte ab da als Fhrer und Reichskanzler.\nDie deutschen Juden wurden ab 1933 zunehmend ausgegrenzt und entrechtet, besonders durch die Nrnberger Gesetze vom 15. September 1935, die Novemberpogrome 1938 und die Arisierung von Unternehmen jdischer Eigentmer sowie zahlreiche weitere Gesetze und Verordnungen, die ihnen schrittweise die Teilnahme am wirtschaftlichen, kulturellen und gesellschaftlichen Leben unmglich machten und sie ihrer Vermgen und Erwerbsmglichkeiten beraubten. Die Folgen der Weltwirtschaftskrise und die Massenarbeitslosigkeit lie er mit einer enormen Ausweitung der Staatsverschuldung bekmpfen: mit Investitionsprogrammen und Arbeitsbeschaffungsmanahmen wie dem Autobahnbau und mit der Aufrstung der Wehrmacht ber das Sys ...

# %%
with open("../dev/hitler-wiki--2", "w") as f:
    f.write(page.content)

# %% [markdown]
# ## Pool

# %%
from multiprocessing import Pool
from services.websearch.webscraper.scraper import webscraper
from services.websearch.googlesearch.google import google
from services.ai.aimodels import embedding_model
from services.ai import aiutils
from services.imindexsearch.indexdb import InMemoryIndexDBFactory


index = InMemoryIndexDBFactory.new()


def prepare_page_results(page_results: list) -> tuple[list, list]:
    prep_results = []
    pages_text_chunks = []
    err_urls = []
    for page in page_results:
        if page.content is not None:
            prep_results.append(page)
            page_chunks = aiutils.chunk_text_with_overlap(page.content)
            pages_text_chunks.append(page_chunks)
        else:
            err_urls.append(page.url)

    return prep_results, pages_text_chunks, err_urls


ggl_queries = [
    "Adolf Hitler"
    ,
    "Eva Braun"
]

vector_queries = [
    "Wie viele Bücher hatte hitler?",
    "Wann starb eva braun"
]

search_links = google.search(ggl_queries, 5)
processes = min(8, len(search_links))
with Pool(processes=processes) as pool:
    print("START")
    pages_results, pages_text_chunks, err_urls = prepare_page_results(pool.map(webscraper.scrape, search_links))
    print("Embeddings", len(pages_text_chunks))
    pages_embeddings = pool.map(embedding_model.embed_batch, pages_text_chunks)

    for page, chunks, embeddings in zip(pages_results, pages_text_chunks, pages_embeddings):
        print("add_batch", page.url, len(chunks))
        index.add_batch(reference=page.url, texts=chunks, embeddings=embeddings)

    vector_results = pool.map(index.search, vector_queries)

print("write results")
for i, results in enumerate(vector_results, 1):
    with open(f"../dev/answer-{i}.txt", "w") as f:
        text = "\n\n===========================\n\n".join([r.text for r in results])
        f.write(text)

print("DOC-COUNT:", len(index._documents))
# Out:
# [16.05.2025 21:25:11,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): www.google.com:443
# [16.05.2025 21:25:11,f] [DEBUG] connectionpool.py https://www.google.com:443 "GET /search?q=Adolf+Hitler&num=7&hl=en&start=0&safe=active HTTP/1.1" 200 None
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): www.google.com:443
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py https://www.google.com:443 "GET /search?q=Eva+Braun&num=8&hl=en&start=0&safe=active HTTP/1.1" 200 None
# START
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): de.wikipedia.org:443
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): www.dhm.de:443
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): de.wikipedia.org:443
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): www.britannica.com:443
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): www.nsdoku.de:443
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): www.dhm.de:443
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py Starting new HTTPS connection (1): www.britannica.com:443
# [16.05.2025 21:25:12,f] [DEBUG] connectionpool.py https://www.nsdoku.de:443 "GET /lexikon/artikel/braun-eva-105 HTTP/1.1" 200 9423
# [16.05.2025 21:25:13,f] [DEBUG] connectionpool.py https://de.wikipedia.org:443 "GET /wiki/Eva_Braun HTTP/1.1" 200 31116
# [16.05.2025 21:25:13,f] [DEBUG] connectionpool.py https://de.wikipedia.org:443 "GET /wiki/Adolf_Hitler HTTP/1.1" 200 197821
# [16.05.2025 21:25:13,f] [DEBUG] connectionpool.py https://www.dhm.de:443 "GET /lemo/biografie/eva-braun HTTP/1.1" 200 6905
# [16.05.2025 21:25:13,f] [DEBUG] connectionpool.py https://www.dhm.de:443 "GET /lemo/biografie/adolf-hitler HTTP/1.1" 200 12505
# [16.05.2025 21:25:13,f] [DEBUG] connectionpool.py https://www.britannica.com:443 "GET /biography/Eva-Braun HTTP/1.1" 200 None
# [16.05.2025 21:25:13,f] [DEBUG] connectionpool.py https://www.britannica.com:443 "GET /biography/Adolf-Hitler HTTP/1.1" 200 None
# Embeddings 7
# [16.05.2025 21:25:14,f] [DEBUG] _base_client.py Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x10a7647c0>, 'json_data': {'input': ["Eva Braun | Facts, Biography, Picture, & Death | Britannica\n\n\nSearch Britannica\n\n\nClick here to search\n\n\nSearch Britannica\n\n\nClick here to search\n\n\n   SUBSCRIBE\n\n\n   SUBSCRIBE\n\n\nLogin\n\nhttps://premium.britannica.com/premium-membership/?utm_source=premium&utm_medium=nav-login-box&utm_campaign=evergreen\n\n\n  SUBSCRIBE\n\n\nHome\nHistory & Society\nScience & Tech\nBiographies\nAnimals & Nature\nGeography & Travel\nArts & Culture\nProCon\nMoney\n\n\nGames & Quizzes\nVideos\nOn This Day\nOne Good Fact\nDictionary\nNew Articles\n\nHistory & Society\n\nLifestyles & Social Issues\nPhilosophy & Religion\nPolitics, Law & Government\nWorld History\n\nScience & Tech\n\nHealth & Medicine\nScience\nTechnology\n\nBiographies\n\nBrowse Biographies\n\nAnimals & Nature\n\nBirds, Reptiles & Other Vertebrates\nBugs, Mollusks & Other Invertebrates\nEnvironment\nFossils & Geologic Time\nMammals\nPlants\n\nGeography & Travel\n\nGeography & Travel\n\nArts & Culture\n\nEntertainment & Pop Culture\nLiterature\nSports & Recreation\nVisual Arts\n\n\nCompanions\nDemystified\nImage Galleries\nLists\nPodcasts\nSpotlight\nSummaries\nTop Questions\n#WTFact\n\n\nBritannica Kids\n\n\n \nAsk the Chatbot\n\n Games & Quizzes\n History & Society\n Science & Tech\n Biographies\n Animals & Nature\n Geography & Travel\n Arts & Culture\n ProCon\n Money\n Videos\n\n\n Eva Braun\n\n\n                    Table of Contents\n                \n\n                            Introduction & Top Questions\n                        \n References & Edit History\n Quick Facts & Related Topics\n\n\n Images & Videos\n\n\n                        Quizzes\n                    \n\n\nAdolf Hitler\n\n\n                        Related Questions\n                    \n\n How did Eva Braun become Adolf Hitler’s mistress?\n\n How did Eva Braun die?\n\n Where is Berlin located?\n\n Berlin is famous for what cultural institutions?\n\n Berlin is the capital of what country?\n\n\n                        Read Next\n                    \n\n\nWas Jesse Owens Snubbed by Adolf Hitler at the Berlin Olympics?\n\n\nFamous Mustaches in History\n\n\n7 Nobel Prize Scandals\n\n\n9 Questions About World War II Answered\n\n\n10 Infographics that Explain the Normandy Invasion During World War II\n\n\n                        Discover\n                    \n\n\nQueen Mab’s Stable: 7 of the Smallest Animals\n\n\nNew Seven Wonders of the World\n\n\n7 Drugs that Changed the World\n\n\nSpies Like Us: 10 Famous Names in the Espionage Game\n\n\nTimeline of the 1980s\n\n\nWhat’s the Difference Between Bison and Buffalo?\n\n\n7 Deadliest Weapons in History\n\n\n\t\n\t\t\t\t\tContents\n\t\t\t\n\n\nEva Braun\nEva Braun, 1944.\n\n(more)\n\n\nEva Braun\n\nwife of Hitler\n\n\n    Ask the Chatbot a Question\n\t\n\n\n\t\n    \n            \n                More Actions\n        \n\n\n\t\n                                Print\n                            \n\n\n\t\n\t\t\t\n\t\t\tCite\n\t\t\n\n\nverifiedCite\n\t\t\n\n\t\t\tWhile every effort has been made to follow citation style rules, there may be some discrepancies.\n\t\t\tPlease refer to the appropriate style manual or other sources if you have any questions.\n\t\t\nSelect Citation Style\n\nMLA\nAPA\nChicago Manual of Style\n\n\nCopy Citation\n\n\n\t\n            \n            Share\n        \n\n\n\t\n            Share\n        \nShare to social media\n\nFacebook\nX\n\nURL\nhttps://www.britannica.com/biography/Eva-Braun\n\n\n\t\n                        Feedback\n                    \n\n\n\t\n                        External Websites\n                    \n\n\n\t\t\tFeedback\n\t\t\n\n\n\t\t\t\tCorrections? Updates? Omissions? Let us know if you have suggestions to improve this article (requires login).\n\t\t\t\n\nFeedback Type\n\nSelect  ...
# [16.05.2025 21:25:14,f] [DEBUG] _base_client.py Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x10a22c890>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py start_tls.started ssl_context=<ssl.SSLContext object at 0x10a75c200> server_hostname='api.openai.com' timeout=5.0
# [16.05.2025 21:25:14,f] [DEBUG] _base_client.py Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0
Quellen\n\n\nGun, Nerin E.: Eva Braun – Hitler. Leben und Schicksal, Kettwig 1968.Görtemaker, Heike B.: Eva Braun. Leben mit Hitler, München 2010.\n\n\nEmpfohlene Zitierweise\n\n                Oliver Hochkeppel: Braun, Eva (publiziert am 16.01.2025), in: nsdoku.lexikon, hrsg. vom NS-Dokumentationszentrum München, URL: https://www.nsdoku.de/lexikon/artikel/braun-eva-105\n            \n\n\nzurück\n\n\nHistory is not the past, it is the  ...
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x10a78f650>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py receive_response_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _base_client.py Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x107dddf50>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py start_tls.started ssl_context=<ssl.SSLContext object at 0x116260200> server_hostname='api.openai.com' timeout=5.0
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1078bc390>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py receive_response_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _base_client.py Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x1162ac7c0>, 'json_data': {'input': ['LeMO Biografie\xa0-\xa0Eva Braun\n\n\nlemo Lebendiges Museum Online\n\n\nSuchen\n\n\nEva Braun 1912-1945\n\n\n1912\n     6. Februar: Eva Braun wird in München als Tochter eines Lehrers geboren.             \n\n1928\n     Nach dem Besuch des Lyzeums beginnt sie eine einjährige Handelsschulausbildung in einem Kloster bei Simbach am Inn.             \n\n1929\n Als Sprechstundenhilfe ist sie einige Monate in München tätig.  Sie wechselt als Bürokraft zum Fotografen Heinrich Hoffmann, wo sie Adolf Hitler kennenlernt. \n\n1931\n     Nach dem Selbstmord der Nichte Hitlers, Geli (eigtl. Angela) Raubal, intensiviert Hitler den Kontakt zu Braun.             \n\n1932\n November: Braun versucht, sich durch einen Schuss in den Hals selbst zu töten. \n\n1935\n Sie verübt einen zweiten Selbstmordversuch mit einer Überdosis Schlafmittel. Hitler will einen Skandal im Zusammenhang mit dem Tod Raubals verhindern und verstärkt den Kontakt zu Braun. Er lässt Hoffmann ein Haus in München kaufen und stellt es ihr zusammen mit einem Mercedes und einem Chauffeur zur Verfügung. \n\nab 1936\n     Nachdem die Halbschwester Hitlers und Mutter von Raubal aus dem Berghof ausgezogen ist, beginnt sich Braun auf dem Obersalzberg einzurichten. Sie tritt     dort nicht als Gastgeberin auf; Hitler bekennt sich nicht öffentlich zu ihr.             \n\n1938\n     In Hitlers Testament wird sie als erste bedacht: Sie soll im Fall seines Todes bis zum Lebensende einen monatlichen Betrag von 1.000,- RM erhalten.             \n\n1944\n     Durch die Hochzeit ihrer Schwester mit einem Verbindungsoffizier Heinrich Himmlers     wird Braun in der Umgebung Hitlers "gesellschaftsfähig".             \n\n1945\n 7. März: Bevor die Rote Armee die Stadt einschließt, fährt Braun nach Berlin.  15. April: Sie bezieht einen Raum im Bunker unter der Reichskanzlei.  28./29. April: Kurz vor Mitternacht werden Braun und Hitler von einem Gauamtsleiter, der als Standesbeamter fungiert, im Bunker getraut. Joseph Goebbels und Martin Bormann sind Trauzeugen. Im Protokoll sind der Notstand und die Kriegstrauung verzeichnet, auch die "arische Abstammung" und "keine Erbkrankheiten" werden vermerkt.  30. April: Eva Braun tötet sich gemeinsam mit Adolf Hitler im Bunker. Sie stirbt durch die Einnahme von Gift.  Die Leichen werden einem Befehl Hitlers zufolge im Garten der Reichskanzlei mit Benzin übergossen und verbrannt. \n\n\nKai-Britt Albrecht\n© Deutsches Historisches Museum, Berlin\n16. September 2014\nText: CC BY NC SA 4.0\n\n\nKontakt\n\n\nImpressum\n\n\nlo'], 'model': 'text-embedding-3-large', 'encoding_format': 'base64'}}
# [16.05.2025 21:25:14,f] [DEBUG] _base_client.py Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x10e3907c0>, 'json_data': {'input': ['Adolf Hitler | History, Biography, Actions, & Facts | Britannica\n\n\nSearch Britannica\n\n\nClick here to search\n\n\nSearch Britannica\n\n\nClick here to search\n\n\n   SUBSCRIBE\n\n\n   SUBSCRIBE\n\n\nLogin\n\nhttps://premium.britannica.com/premium-membership/?utm_source=premium&utm_medium=nav-login-box&utm_campaign=evergreen\n\n\n  SUBSCRIBE\n\n\nHome\nHistory & Society\nScience & Tech\nBiographies\nAnimals & Nature\nGeography & Travel\nArts & Culture\nProCon\nMoney\n\n\nGames & Quizzes\nVideos\nOn This Day\nOne Good Fact\nDictionary\nNew Articles\n\nHistory & Society\n\nLifestyles & Social Issues\nPhilosophy & Religion\nPolitics, Law & Government\nWorld History\n\nScience & Tech\n\nHealth & Medicine\nScience\nTechnology\n\nBiographies\n\nBrowse Biographies\n\nAnimals & Nature\n\nBirds, Reptiles & Other Vertebrates\nBugs, Mollusks & Other Invertebrates\nEnvironment\nFossils & Geologic Time\nMammals\nPlants\n\nGeography & Travel\n\nGeography & Travel\n\nArts & Culture\n\nEntertainment & Pop Culture\nLiterature\nSports & Recreation\nVisual Arts\n\n\nCompanions\nDemystified\nImage Galleries\nLists\nPodcasts\nSpotlight\nSummaries\nTop Questions\n#WTFact\n\n\nBritannica Kids\n\n\n \nAsk the Chatbot\n\n Games & Quizzes\n History & Society\n Science & Tech\n Biographies\n Animals & Nature\n Geography & Travel\n Arts & Culture\n ProCon\n Money\n Videos\n\n\n Adolf Hitler\n\n\n                    Table of Contents\n                \nIntroduction & Top QuestionsEarly lifeRise to powerHitler’s life and habitsDictator, 1933–39World War IIHitler’s place in history\n Quotes\n References & Edit History\n Quick Facts & Related Topics\n\n\n Images & Videos\n\n\n                        For Students\n                    \n\n\nPop Quiz: 17 Things to Know About World War II\n\n\nAdolf Hitler summary\n\n\n                        Quizzes\n                    \n\n\nWorld War II Quiz\n\n\nAdolf Hitler\n\n\n                        Related Questions\n                    \n\n Why was Adolf Hitler significant?\n\n How did Adolf Hitler rise to power?\n\n Why did Adolf Hitler start World War II?\n\n Who were Adolf Hitler’s most important officers?\n\n How did Adolf Hitler die?\n\n\n                        Read Next\n                    \n\n\n9 Things You Might Not Know About Adolf Hitler\n\n\n7 Nobel Prize Scandals\n\n\n75th Anniversary of Operation Barbarossa\n\n\nWhy Was Nazi Germany Called the Third Reich?\n\n\nFamous Mustaches in History\n\n\n                        Discover\n                    \n\n\nTimeline of the 1980s\n\n\nCannibalism: Cultures, Cures, Cuisine, and Calories\n\n\nWhat If the President Is Impeached?\n\n\nDid Marie-Antoinette Really Say “Let Them Eat Cake”?\n\n\nWho Invented the Internet?\n\n\nWhat Is the Emoluments Clause?\n\n\nHow Deadly Is Quicksand?\n\n\nAdolf Hitler\nNazi Party leader Adolf Hitler, c. 1933.\n\n(more)\n\n\nAdolf Hitler\n\ndictator of Germany\n\n\n        Simplify\n        &nbspThis\xa0\n        Article\n    \n\n\n    Ask the Chatbot\n\t\n\n\n\t\n                                Print\n                            \n\n\nprint\n\t\t\tPrint\n\t\t\n\n\t\t\tPlease select which sections you would like to print:\n\t\t\n\n\nTable Of Contents\n\n\n\t\n\t\t\t\n\t\t\tCite\n\t\t\n\n\nverifiedCite\n\t\t\n\n\t\t\tWhile every effort has been made to follow citation style rules, there may be some discrepancies.\n\t\t\tPlease refer to the appropriate style manual or other sources if you have any questions.\n\t\t\nSelect Citation Style\n\nMLA\nAPA\nChicago Manual of Style\n\n\nCopy Citation\n\n\n\t\n            \n            Share\n        \n\n\n\t\n            Share\n        \nShare to social media\n\nFacebook\nX\n\nURL\nhttps://www.britannica.com/biography/Adolf-Hitler\n\n\n\t\n                        Feedback ...
# [16.05.2025 21:25:14,f] [DEBUG] _base_client.py Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x132244c20>, 'json_data': {'input': ['Eva Braun – Wikipedia\n\n\nZum Inhalt springen\n\n\nSuche\n\n\nSuchen\n\n\nEva Braun\n\n\n80 Sprachen\n\n\nAfrikaansالعربيةمصرىAzərbaycancaBikol CentralБеларускаяБеларуская (тарашкевіца)БългарскиবাংলাBosanskiCatalàکوردیČeštinaCymraegDanskΕλληνικάEnglishEsperantoEspañolEestiEuskaraفارسیSuomiFrançaisFryskGaeilgeGalegoעבריתहिन्दीHrvatskiMagyarՀայերենBahasa IndonesiaÍslenskaItaliano日本語Jawaქართულიಕನ್ನಡ한국어LatinaLëtzebuergeschLietuviųLatviešuMalagasyМакедонскиമലയാളംМонголBahasa MelayuनेपालीNederlandsNorsk nynorskNorsk bokmålਪੰਜਾਬੀPolskiPiemontèisپنجابیPortuguêsRomânăРусскийSrpskohrvatski / српскохрватскиසිංහලSimple EnglishSlovenčinaSlovenščinaShqipСрпски / srpskiSvenskaதமிழ்ไทยTagalogTürkçeУкраїнськаاردوOʻzbekcha / ўзбекчаTiếng ViệtWinaray吴语中文粵語\n\nLinks bearbeiten\n\n\naus Wikipedia, der freien Enzyklopädie\n\n\nDer Titel dieses Artikels ist mehrdeutig. Weitere Bedeutungen sind unter Eva Braun (Begriffsklärung) aufgeführt.\n\nEva Braun, späte 1930er Jahre\nEva Anna Paula Braun (* 6. Februar 1912 in München; † 30. April 1945 in Berlin als am 29.\xa0April 1945 verheiratete Eva Hitler) war, wahrscheinlich seit 1932, die der Öffentlichkeit verheimlichte Geliebte Adolf Hitlers. Beide heirateten einen Tag vor dem gemeinsamen Suizid im umkämpften Berlin, kurz vor der bedingungslosen Kapitulation der Wehrmacht im Zweiten Weltkrieg.\n\n\nLeben und Wirken\nEva Brauns Familie\nFamilie\nDie Eltern von Eva Braun, Friedrich (genannt „Fritz“, * 1879) und Franziska (Fanny) Katharina Braun (geb. Kronberger, * 1885), überlebten ihre Tochter. Sie starben am 22.\xa0Januar 1964 bzw. 13.\xa0Januar 1976 in Ruhpolding (Oberbayern) und sind dort auf dem neuen Bergfriedhof begraben. Der Vater war von Beruf Gewerbestudienrat und Kunstschreiner.\nEva Braun hatte zwei Schwestern, Ilse (1908–1979) und Margarete (1915–1987; genannt „Gretl“). Ilse war dem Nationalsozialismus gegenüber sehr skeptisch eingestellt. Sie hielt sich we
ückgreifen.24. Mai: Er übersiedelt nach München. \n\n1914\n Hier tritt er als Kriegsfreiwilliger in das Bayerische Reserve-Infanterie-Regiment Nr. 16 (später Regiment "List") ein.  Dezember: Auszeichnung mit dem Eisernen Kreuz II. Klasse. \n\n1916\n     Oktober: Schwere Beinverwundung an der Westfront.             \n\n1917\n     5. März: Wieder genesen, meldet sich Hitler zu seiner Einheit zurück.             \n\n1918\n August: Auszeichnung mit dem Eisernen Kreuz I. Klasse.  15. Oktober: Bei einem Gasangriff erleidet er eine Vergiftung, die zu zeitweiser Erblindung führt. Ende November: Nach einem Lazarettaufenthalt in Pasewalk, wo er das Kriegsende erlebt, kehrt er zum Infanterieregiment 2 nach München zurück und ist für die Reichswehr als "Verbindungsmann" und "Aufklärungsredner" tätig. \n\n1919\n     Juni: Hitler wird von seiner Einheit zur Teilnahme an einem Rednerkurs für ausgewählte "Propagandaleute" an der Universität München vorgeschlagen und     zeichnet sich dabei als talentierter Redner aus.             August: In seinen ersten schriftlichen politischen Notizen hebt er als vordringlichstes Ziel die "Entfernung der Juden überhaupt" hervor.             12. September: Hitler besucht eine Versammlung der Deutschen     Arbeiterpartei (DAP) und tritt ihr wenige Tage später mit der Mitgliedsnummer 555 bei. Die Partei hatte ihre Zählung bei 500 begonnen, um eine größere     Mitgliederschaft vorzutäuschen.             16. Oktober: Hitler hält seine erste politische Rede vor Mitgliedern der DAP.             \n\n1920\n Februar: Mitarbeit am Programm der in Nationalsozialistische Deutsche Arbeiterpartei (NSDAP) umbenannten Partei.  31. März: Hitler wird aus der Reichswehr entlassen und widmet sich fortan der Parteiarbeit. \n\n1921\n     29. Juli: Als Agitator unterdessen unentbehrlich geworden und über die Grenzen Münchens bekannt, gelingt es ihm auf einer außerordentlichen     Mitgliederversammlung der NSDAP, die Führung der Partei mit diktatorischen Vollmachten zu übernehmen.             \n\n1923\n     9. November: Der Hitler-Putsch in München wird von Regierungstruppen mit     Waffengewalt niedergeschlagen. Die NSDAP wird am folgenden Tag verboten. Hitler flieht und wird zwei Tage später im bayerischen Uffing verhaftet.             \n\n1924\n 26. Februar: Hitler wird zusammen mit Ernst Röhm, General Erich Ludendorff u.a. vor dem Münchener Volksgericht des Hochverrats angeklagt und schließlich zu fünfjähriger Festungshaft verurteilt. Die Prozessverhandlungen benutzt Hitler als Forum für seine antirepublikanische Agitation. ', 'en überhaupt" hervor.             12. September: Hitler besucht eine Versammlung der Deutschen     Arbeiterpartei (DAP) und tritt ihr wenige Tage später mit der Mitgliedsnummer 555 bei. Die Partei hatte ihre Zählung bei 500 begonnen, um eine größere     Mitgliederschaft vorzutäuschen.             ...
# [16.05.2025 21:25:14,f] [DEBUG] _base_client.py Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x131a1e350>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py receive_response_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x10da04650>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py receive_response_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1069d7ad0>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py start_tls.started ssl_context=<ssl.SSLContext object at 0x1069a4200> server_hostname='api.openai.com' timeout=5.0
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x105c58650>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_headers.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py send_request_body.complete
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py receive_response_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:14,f] [DEBUG] _trace.py receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 16 May 2025 19:25:14 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-large'), (b'openai-organization', b'emtec-e-v'), (b'openai-processing-ms', b'136'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'via', b'envoy-router-77b75fd56c-d7pv9'), (b'x-envoy-upstream-service-time', b'138'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999375'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'7ms'), (b'x-request-id', b'req_bb0f18dad0f9d349045933e4d35912a3'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm
path=/; expires=Fri, 16-May-25 19:55:15 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=1.bJb6qgsD7AniQiaKQfhX_fAfAlBaT10hvE_7Rnpjk-1747423515274-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'940d4285dca7e51e-TXL'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# [16.05.2025 21:25:15,f] [INFO] _client.py HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [16.05.2025 21:25:15,f] [DEBUG] _trace.py receive_response_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:15,f] [DEBUG] _trace.py receive_response_body.complete
# [16.05.2025 21:25:15,f] [DEBUG] _trace.py response_closed.started
# [16.05.2025 21:25:15,f] [DEBUG] _trace.py response_closed.complete
# [16.05.2025 21:25:15,f] [DEBUG] _base_client.py HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers([('date', 'Fri, 16 May 2025 19:25:15 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-allow-origin', '*'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-model', 'text-embedding-3-large'), ('openai-organization', 'emtec-e-v'), ('openai-processing-ms', '324'), ('openai-version', '2020-10-01'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('via', 'envoy-router-54f9f45cdb-8n8jj'), ('x-envoy-upstream-service-time', '327'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '5000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '4992592'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '88ms'), ('x-request-id', 'req_02425665fd5c09485e42dedd5f146a19'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=Pmx8ZWd2sv2C0xr3.AbePHMADppwbdeIKZM622Av8.Q-1747423515-1.0.1.1-7dJKc9XC25YJUHWp5r790PqJqoG6uiQOTkYuw0qI2YHhknolyj1vjmptIh9hbWZO0utMNdetWgI9eiM3rCZIOqZLts7y478Yse9M3AjGKhM; path=/; expires=Fri, 16-May-25 19:55:15 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=mjX3ZKmZnW93UFjQBPhH1gRS7EXQ9Imz0mtzAYZOZkM-1747423515228-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '940d4285bbe8e50b-TXL'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# [16.05.2025 21:25:15,f] [DEBUG] _base_client.py request_id: req_02425665fd5c09485e42dedd5f146a19
# [16.05.2025 21:25:15,f] [DEBUG] _trace.py receive_response_body.complete
# [16.05.2025 21:25:15,f] [DEBUG] _trace.py response_closed.started
# [16.05.2025 21:25:15,f] [DEBUG] _trace.py response_closed.complete
# [16.05.2025 21:25:15,f] [DEBUG] _base_client.py HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers([('date', 'Fri, 16 May 2025 19:25:15 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-allow-origin', '*'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-model', 'text-embedding-3-large'), ('openai-organization', 'emtec-e-v'), ('openai-processing-ms', '479'), ('openai-version', '2020-10-01'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('via', 'envoy-router-5fcfd9bb69-f4z5t'), ('x-envoy-upstream-service-time', '483'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '5000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '4995739'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '51ms'), ('x-request-id', 'req_0d87b501485ac313a85ad46255c0abc0'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=2EzH10UYrPe9suI8Ok8m7xg1g2aQmW9FBtHUQfYLf_g-1747423515-1.0.1.1-6KQ3A7LxtAbHNUBIvjSMlwrh6WB8IHMg52qjxbPm1ndbIjiQnALWnNPL2z7mwz_yMR8RcbK2x5ICUe8A4e2JmzTzCGZOoMK9WEbAGEUz0Wo; path=/; expires=Fri, 16-May-25 19:55:15 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=1.bJb6qgsD7AniQiaKQfhX_fAfAlBaT10hvE_7Rnpjk-1747423515274-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '940d4285dca7e51e-TXL'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# [16.05.2025 21:25:15,f] [DEBUG] _base_client.py request_id: req_0d87b501485ac313a85ad46255c0abc0
# add_batch https://de.wikipedia.org/wiki/Adolf_Hitler 118
# add_batch https://www.britannica.com/biography/Adolf-Hitler 5
# add_batch https://www.dhm.de/lemo/biografie/adolf-hitler 5
# add_batch https://de.wikipedia.org/wiki/Eva_Braun 7
# add_batch https://www.britannica.com/biography/Eva-Braun 3
# add_batch https://www.dhm.de/lemo/biografie/eva-braun 1
# add_batch https://www.nsdoku.de/lexikon/artikel/braun-eva-105 2
# [16.05.2025 21:25:17,f] [DEBUG] _base_client.py Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x1162ac7c0>, 'json_data': {'input': 'Wann starb eva braun', 'model': 'text-embedding-3-large', 'encoding_format': 'base64'}}
# [16.05.2025 21:25:17,f] [DEBUG] _base_client.py Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py send_request_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py send_request_headers.complete
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py send_request_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py send_request_body.complete
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py receive_response_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:17,f] [DEBUG] _base_client.py Request options: {'method': 'post', 'url': '/embeddings', 'files': None, 'post_parser': <function Embeddings.create.<locals>.parser at 0x11e881120>, 'json_data': {'input': 'Wie viele Bücher hatte hitler?', 'model': 'text-embedding-3-large', 'encoding_format': 'base64'}}
# [16.05.2025 21:25:17,f] [DEBUG] _base_client.py Sending HTTP Request: POST https://api.openai.com/v1/embeddings
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py connect_tcp.started host='api.openai.com' port=443 local_address=None timeout=5.0 socket_options=None
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11e8ac3d0>
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py start_tls.started ssl_context=<ssl.SSLContext object at 0x119db34a0> server_hostname='api.openai.com' timeout=5.0
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 16 May 2025 19:25:17 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-large'), (b'openai-organization', b'emtec-e-v'), (b'openai-processing-ms', b'77'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'via', b'envoy-router-5d679b4688-zb47k'), (b'x-envoy-upstream-service-time', b'79'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999994'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_767041b99be5cdcde43de7ca11181368'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Content-Type-Options', b'nosniff'), (b'Server', b'cloudflare'), (b'CF-RAY', b'940d42977b6de50b-TXL'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# [16.05.2025 21:25:17,f] [INFO] _client.py HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py receive_response_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x11e8a3fd0>
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py send_request_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py send_request_headers.complete
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py send_request_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py send_request_body.complete
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py receive_response_headers.started request=<Request [b'POST']>
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py receive_response_body.complete
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py response_closed.started
# [16.05.2025 21:25:17,f] [DEBUG] _trace.py response_closed.complete
# [16.05.2025 21:25:17,f] [DEBUG] _base_client.py HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers({'date': 'Fri, 16 May 2025 19:25:17 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-origin': '*', 'access-control-expose-headers': 'X-Request-ID', 'openai-model': 'text-embedding-3-large', 'openai-organization': 'emtec-e-v', 'openai-processing-ms': '77', 'openai-version': '2020-10-01', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'via': 'envoy-router-5d679b4688-zb47k', 'x-envoy-upstream-service-time': '79', 'x-ratelimit-limit-requests': '5000', 'x-ratelimit-limit-tokens': '5000000', 'x-ratelimit-remaining-requests': '4999', 'x-ratelimit-remaining-tokens': '4999994', 'x-ratelimit-reset-requests': '12ms', 'x-ratelimit-reset-tokens': '0s', 'x-request-id': 'req_767041b99be5cdcde43de7ca11181368', 'cf-cache-status': 'DYNAMIC', 'x-content-type-options': 'nosniff', 'server': 'cloudflare', 'cf-ray': '940d42977b6de50b-TXL', 'content-encoding': 'br', 'alt-svc': 'h3=":443"; ma=86400'})
# [16.05.2025 21:25:17,f] [DEBUG] _base_client.py request_id: req_767041b99be5cdcde43de7ca11181368
# write results
# DOC-COUNT: 141
# [16.05.2025 21:25:18,f] [DEBUG] _trace.py receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Fri, 16 May 2025 19:25:18 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'access-control-allow-origin', b'*'), (b'access-control-expose-headers', b'X-Request-ID'), (b'openai-model', b'text-embedding-3-large'), (b'openai-organization', b'emtec-e-v'), (b'openai-processing-ms', b'70'), (b'openai-version', b'2020-10-01'), (b'strict-transport-security', b'max-age=31536000; includeSubDomains; preload'), (b'via', b'envoy-router-6d87b587bb-4mzgj'), (b'x-envoy-upstream-service-time', b'72'), (b'x-ratelimit-limit-requests', b'5000'), (b'x-ratelimit-limit-tokens', b'5000000'), (b'x-ratelimit-remaining-requests', b'4999'), (b'x-ratelimit-remaining-tokens', b'4999993'), (b'x-ratelimit-reset-requests', b'12ms'), (b'x-ratelimit-reset-tokens', b'0s'), (b'x-request-id', b'req_a55fbf176b387e94411c31a59a704c06'), (b'cf-cache-status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=WmeduTVXbMIb0C0_WcK0I6tQqQEqVKyAQlBAwFaK6gc-1747423518-1.0.1.1-kGcl3CUWB8M_mfRXXD7sy1UVh23K26p_8hfB2x6.eofauFSINfI8NAOP89JFfxi1UIGxQntFiHCnYhKLaF_GUVMSXuSywDlIdoyGrQPpHrI; path=/; expires=Fri, 16-May-25 19:55:18 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'X-Content-Type-Options', b'nosniff'), (b'Set-Cookie', b'_cfuvid=KG3h4Ia4L8chLfgpctrnUgWBVyX_eFQaXYDP4D6PXro-1747423518206-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'940d429a5d04e527-TXL'), (b'Content-Encoding', b'br'), (b'alt-svc', b'h3=":443"; ma=86400')])
# [16.05.2025 21:25:18,f] [INFO] _client.py HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [16.05.2025 21:25:18,f] [DEBUG] _trace.py receive_response_body.started request=<Request [b'POST']>
# [16.05.2025 21:25:18,f] [DEBUG] _trace.py receive_response_body.complete
# [16.05.2025 21:25:18,f] [DEBUG] _trace.py response_closed.started
# [16.05.2025 21:25:18,f] [DEBUG] _trace.py response_closed.complete
# [16.05.2025 21:25:18,f] [DEBUG] _base_client.py HTTP Response: POST https://api.openai.com/v1/embeddings "200 OK" Headers([('date', 'Fri, 16 May 2025 19:25:18 GMT'), ('content-type', 'application/json'), ('transfer-encoding', 'chunked'), ('connection', 'keep-alive'), ('access-control-allow-origin', '*'), ('access-control-expose-headers', 'X-Request-ID'), ('openai-model', 'text-embedding-3-large'), ('openai-organization', 'emtec-e-v'), ('openai-processing-ms', '70'), ('openai-version', '2020-10-01'), ('strict-transport-security', 'max-age=31536000; includeSubDomains; preload'), ('via', 'envoy-router-6d87b587bb-4mzgj'), ('x-envoy-upstream-service-time', '72'), ('x-ratelimit-limit-requests', '5000'), ('x-ratelimit-limit-tokens', '5000000'), ('x-ratelimit-remaining-requests', '4999'), ('x-ratelimit-remaining-tokens', '4999993'), ('x-ratelimit-reset-requests', '12ms'), ('x-ratelimit-reset-tokens', '0s'), ('x-request-id', 'req_a55fbf176b387e94411c31a59a704c06'), ('cf-cache-status', 'DYNAMIC'), ('set-cookie', '__cf_bm=WmeduTVXbMIb0C0_WcK0I6tQqQEqVKyAQlBAwFaK6gc-1747423518-1.0.1.1-kGcl3CUWB8M_mfRXXD7sy1UVh23K26p_8hfB2x6.eofauFSINfI8NAOP89JFfxi1UIGxQntFiHCnYhKLaF_GUVMSXuSywDlIdoyGrQPpHrI; path=/; expires=Fri, 16-May-25 19:55:18 GMT; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('x-content-type-options', 'nosniff'), ('set-cookie', '_cfuvid=KG3h4Ia4L8chLfgpctrnUgWBVyX_eFQaXYDP4D6PXro-1747423518206-0.0.1.1-604800000; path=/; domain=.api.openai.com; HttpOnly; Secure; SameSite=None'), ('server', 'cloudflare'), ('cf-ray', '940d429a5d04e527-TXL'), ('content-encoding', 'br'), ('alt-svc', 'h3=":443"; ma=86400')])
# [16.05.2025 21:25:18,f] [DEBUG] _base_client.py request_id: req_a55fbf176b387e94411c31a59a704c06
